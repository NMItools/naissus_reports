# %%
import sys
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, select, engine

print('Python v' + sys.version)
print('------------------------------------------------------------------------------')
print('Pandas v' + pd.__version__)
print('SQLAlchemy v' + sqlalchemy.__version__)
# Out:
# Python v3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# ------------------------------------------------------------------------------
# Pandas v1.1.4
# SQLAlchemy v1.3.20

# %%
DB = {
    'drivername': 'mssql+pyodbc',
    'servername': 'VERDI',
    'port': '1433',
    'username': 'nebojsa',
    'password': 'tras659',
    'database': 'SANiN',
    'driver': 'SQL Server Native Client 11.0',
#     'trusted_connection': 'yes',  
#     'legacy_schema_aliasing': 'False'
}

# conn_string = DB['drivername'] + '://' + DB['username'] +':' + DB['password'] + '@' + DB['servername'] + ':' + DB['port'] + '/' + DB['database'] + '?' + 'driver=' + DB['driver']
# print(conn_string)

#  mssql+pyodbc://nebojsa:tras659@VERDI:1433/SANiN?driver=SQL Server Native Client 11.0
    
# Kreiranje konekcije sa MSSQL
engine = create_engine(
    DB['drivername'] 
    + '://' 
    + DB['username'] 
    +':'
    + DB['password'] 
    + '@' 
    + DB['servername'] 
    + ':' 
    + DB['port']
    + '/' 
    + DB['database'] 
    + '?' 
    + 'driver=' 
    + DB['driver'])
conn = engine.connect()

# Required for querying tables
metadata = MetaData(conn)

# %%
df1 = pd.read_sql_query("[dbo].[mp_scada] 'SCADA_2021'", engine)
df1.head()
# Out:
#                 vreme  I-1-LJB  I-BBV-2  BBV_II-8  I-2-DIV  I-3-MOK  I-4-KR1  \
# 0 2021-01-01 00:00:00     99.6     60.8     30.80    147.2    313.6      0.0
# 1 2021-01-01 00:10:00     98.8     60.8     10.35    146.4    313.6      0.0
# 2 2021-01-01 00:20:00     99.2     60.8      0.02    147.2    313.6      0.0
# 3 2021-01-01 00:30:00     99.6     60.8      0.02    147.2    313.6      0.0
# 4 2021-01-01 00:40:00     99.2     60.8      0.02    146.4    313.6      0.0
#
#    I-4-KR2  I-V-6  I-5-STU  ...  M-20-100-15  M-20-30-14  M-20-30-22  \
# 0      0.0  534.5   242.73  ...        19.44        2.10        64.8
# 1      0.0  544.8   242.70  ...        18.48        1.68        65.2
# 2      0.0  524.8   242.82  ...        18.96        0.02        64.4
# 3      0.0  529.9   242.85  ...        19.76        1.04        64.4
# 4      0.0  528.0   242.76  ...        19.84        2.00        64.0
#
#    M-20-40-18  M-20-40-21  M-20-50-23  M-40-50-16  M-50-60-19  M-80-140-29  \
# ...

# %%
df2 = pd.read_sql_query("[dbo].[mp_scada_rez] 'SCADA_2021'", engine)
df2.head()
# Out:
#                 vreme  Vinik  Krupac  Bubanj  Matejevac_2  Miljkovac  \
# 0 2021-01-01 00:00:00   3.08    3.24    3.93         2.93       2.01
# 1 2021-01-01 00:10:00   3.10    3.22    4.00         2.81       1.94
# 2 2021-01-01 00:20:00   3.10    3.20    4.06         2.69       1.94
# 3 2021-01-01 00:30:00   3.12    3.15    4.12         2.60       1.95
# 4 2021-01-01 00:40:00   3.12    3.11    4.10         2.59       1.96
#
#    Toplik_B  Toplik_PS
# 0      6.43       2.31
# 1      6.43       2.30
# 2      6.43       2.30
# 3      6.43       2.31
# 4      6.43       2.31

# %%
df3 = pd.read_sql_query("[dbo].[mp_scada_p] 'SCADA_2021'", engine)
df3.head()
# Out:
#                 vreme  I-1-LJB  I-BBV-2  BBV_II-8  I-2-DIV  I-3-MOK  I-4-KR1  \
# 0 2021-01-01 00:00:00     7.41     8.34      1.98     1.38     1.32     4.65
# 1 2021-01-01 00:10:00     7.41     8.34      1.94     1.39     1.33     4.64
# 2 2021-01-01 00:20:00     7.43     8.34      1.92     1.38     1.33     4.63
# 3 2021-01-01 00:30:00     7.43     8.34      1.92     1.38     1.33     4.63
# 4 2021-01-01 00:40:00     7.41     8.34      1.93     1.39     1.32     4.63
#
#    I-4-KR2  I-V-6  I-5-STU  ...  M-20-100-15  M-20-30-14  M-20-30-22  \
# 0      0.0   5.15      0.0  ...          6.2        3.94        6.32
# 1      0.0   5.13      0.0  ...          6.2        3.96        6.28
# 2      0.0   5.16      0.0  ...          6.2        3.96        6.28
# 3      0.0   5.11      0.0  ...          6.2        3.95        6.28
# 4      0.0   5.08      0.0  ...          6.2        3.95        6.28
#
#    M-20-40-18  M-20-40-21  M-20-50-23  M-40-50-16  M-50-60-19  M-80-140-29  \
# ...

# %%
TableName = 'SCADA_2021'

df1.to_csv(TableName+'.csv', index=False)

df2.to_csv(TableName+'_REZ.csv', index=False)

df3.to_csv(TableName+'_p.csv', index=False)

print('Done')
# Out:
# Done

# %%
print(df1.columns) 
print("")
print(df2.columns) 
print("")
print(df3.columns)
# Out:
# Index(['vreme', 'I-1-LJB', 'I-BBV-2', 'BBV_II-8', 'I-2-DIV', 'I-3-MOK',
#        'I-4-KR1', 'I-4-KR2', 'I-V-6', 'I-5-STU', 'MRB', 'III-8', 'M-70-81-17',
#        'I-7-M10', 'I-7-M11', 'I-7-M2', 'I-6-MLJ', 'M-20-992-13', 'M-20-992-27',
#        'M-170-992-34', 'M-190-21-35', 'M-100-120-9', 'M-10-100-11',
#        'M-10-20-1', 'M-10-20-12', 'M-10-40-3', 'M-10-40-4', 'M-10-50-5',
#        'M-10-60-6', 'M-10-80-7', 'M-10-80-8', 'M-10-90-10', 'M-10-90-32',
#        'M-120-150-28', 'M-20-100-15', 'M-20-30-14', 'M-20-30-22', 'M-20-40-18',
#        'M-20-40-21', 'M-20-50-23', 'M-40-50-16', 'M-50-60-19', 'M-80-140-29',
#        'M-90-91-20'],
#       dtype='object')
#
# Index(['vreme', 'Vinik', 'Krupac', 'Bubanj', 'Matejevac_2', 'Miljkovac',
#        'Toplik_B', 'Toplik_PS'],
#       dtype='object')
#
# Index(['vreme', 'I-1-LJB', 'I-BBV-2', 'BBV_II-8', 'I-2-DIV', 'I-3-MOK',
#        'I-4-KR1', 'I-4-KR2', 'I-V-6', 'I-5-STU', 'MRB', 'III-8', 'M-70-81-17',
# ...

# %%
# provere
print(type(df1.vreme))
print(type(df1.vreme[0]))

print(type(df1['I-1-LJB'])) 
print(type(df1['I-1-LJB'][0]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.float64'>

# %%
df1.set_index("vreme", inplace=True)
df1
# Out:
#                      I-1-LJB  I-BBV-2  BBV_II-8  I-2-DIV  I-3-MOK  I-4-KR1  \
# vreme
# 2021-01-01 00:00:00     99.6     60.8     30.80    147.2    313.6      0.0
# 2021-01-01 00:10:00     98.8     60.8     10.35    146.4    313.6      0.0
# 2021-01-01 00:20:00     99.2     60.8      0.02    147.2    313.6      0.0
# 2021-01-01 00:30:00     99.6     60.8      0.02    147.2    313.6      0.0
# 2021-01-01 00:40:00     99.2     60.8      0.02    146.4    313.6      0.0
# ...                      ...      ...       ...      ...      ...      ...
# 2021-12-31 08:40:00    259.2    197.6      0.01    278.4    254.4      0.0
# 2021-12-31 08:50:00    259.2    198.4      0.01    278.4    252.8      0.0
# 2021-12-31 09:00:00    259.2    198.4      0.01    278.4    251.2      0.0
# 2021-12-31 09:10:00    259.2    198.4      0.01    278.4    252.8      0.0
# 2021-12-31 09:20:00    259.2    197.6      0.01    278.4    252.8      0.0
#
# ...

# %%
df2.set_index("vreme", inplace=True)
df2
# Out:
#                      Vinik  Krupac  Bubanj  Matejevac_2  Miljkovac  Toplik_B  \
# vreme
# 2021-01-01 00:00:00   3.08    3.24    3.93         2.93       2.01      6.43
# 2021-01-01 00:10:00   3.10    3.22    4.00         2.81       1.94      6.43
# 2021-01-01 00:20:00   3.10    3.20    4.06         2.69       1.94      6.43
# 2021-01-01 00:30:00   3.12    3.15    4.12         2.60       1.95      6.43
# 2021-01-01 00:40:00   3.12    3.11    4.10         2.59       1.96      6.43
# ...                    ...     ...     ...          ...        ...       ...
# 2021-12-31 08:50:00   4.18    2.73    3.99         2.78       2.67      6.43
# 2021-12-31 09:00:00   4.18    2.82    4.03         2.92       2.66      6.43
# 2021-12-31 09:10:00   4.16    2.91    4.06         3.04       2.63      6.43
# 2021-12-31 09:20:00   4.16    3.00    4.09         3.07       2.60      6.43
# 2021-12-31 09:30:00    NaN     NaN     NaN         3.10       2.54      6.43
#
#                      Toplik_PS
# ...

# %%
df3.set_index("vreme", inplace=True)
df3
# Out:
#                      I-1-LJB  I-BBV-2  BBV_II-8  I-2-DIV  I-3-MOK  I-4-KR1  \
# vreme
# 2021-01-01 00:00:00     7.41     8.34      1.98     1.38     1.32     4.65
# 2021-01-01 00:10:00     7.41     8.34      1.94     1.39     1.33     4.64
# 2021-01-01 00:20:00     7.43     8.34      1.92     1.38     1.33     4.63
# 2021-01-01 00:30:00     7.43     8.34      1.92     1.38     1.33     4.63
# 2021-01-01 00:40:00     7.41     8.34      1.93     1.39     1.32     4.63
# ...                      ...      ...       ...      ...      ...      ...
# 2021-12-31 08:40:00     7.61     8.32      1.93     1.63     1.40     4.61
# 2021-12-31 08:50:00     7.62     8.29      1.94     1.63     1.41     4.61
# 2021-12-31 09:00:00     7.62     8.28      1.94     1.63     1.41     4.63
# 2021-12-31 09:10:00     7.62     8.29      1.93     1.63     1.41     4.63
# 2021-12-31 09:20:00     7.61     8.32      1.93     1.63     1.40     4.63
#
# ...

# %%
# Close connection
conn.close()

# %%
print('GOTOVO!')
# Out:
# GOTOVO!
